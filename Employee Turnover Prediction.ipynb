# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("D:\Dataset\WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# 25%        491.250000                 2.000000    48.000000        2.000000
# 50%       1020.500000                 3.000000    66.000000        3.000000
# 75%       1555.750000                 4.000000    83.750000        3.000000
# max       2068.000000                 4.000000   100.000000        4.000000
#
#           JobLevel  ...  RelationshipSatisfaction  StandardHours  \
# count  1470.000000  ...               1470.000000         1470.0
# mean      2.063946  ...                  2.712245           80.0
# std       1.106940  ...                  1.081209            0.0
# min       1.000000  ...                  1.000000           80.0
# 25%       1.000000  ...                  2.000000           80.0
# 50%       2.000000  ...                  3.000000           80.0
# 75%       3.000000  ...                  4.000000           80.0
# max       5.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 26 columns]

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
sns.countplot(data['Attrition'])
# Out:
# C:\Users\Thamotharan\AppData\Roaming\Python\Python311\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
plt.subplots(figsize=(12,5))
sns.countplot(x = 'Age' , hue = 'Attrition' , data = data )
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
for column in data.columns:
    if data[column].dtype == object:
        print(str(column) +' : ' +str(data[column].unique()))
        print(data[column].value_counts())
        print('________________________________________________________________________________________________________________')
# Out:
# Attrition : ['Yes' 'No']
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
# ________________________________________________________________________________________________________________
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
# ________________________________________________________________________________________________________________
# Department : ['Sales' 'Research & Development' 'Human Resources']
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
# ________________________________________________________________________________________________________________
# EducationField : ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64
# ________________________________________________________________________________________________________________
# Gender : ['Female' 'Male']
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64
# ________________________________________________________________________________________________________________
# JobRole : ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64
# ________________________________________________________________________________________________________________
# MaritalStatus : ['Single' 'Married' 'Divorced']
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64
# ________________________________________________________________________________________________________________
# Over18 : ['Y']
# Over18
# Y    1470
# Name: count, dtype: int64
# ________________________________________________________________________________________________________________
# OverTime : ['Yes' 'No']
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64
# ________________________________________________________________________________________________________________

# %%
data['StandardHours'].unique()
# Out:
# array([80], dtype=int64)

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

for column in data.columns:
    if data[column].dtype ==np.number:
        continue
    data[column] = LabelEncoder().fit_transform(data[column])
# Out:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:
# C:\Users\Thamotharan\AppData\Local\Temp\ipykernel_130352\4131487561.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype ==np.number:

# %%
data['Age_Years'] = data['Age']

# %%
data = data.drop(columns = 'Age')

# %%
data
# Out:
#       Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0             1               2        624           2                 0
# 1             0               1        113           1                 7
# 2             1               2        805           1                 1
# 3             0               1        820           1                 2
# 4             0               2        312           1                 1
# ...         ...             ...        ...         ...               ...
# 1465          0               1        494           1                22
# 1466          0               2        327           1                 5
# 1467          0               2         39           1                 3
# 1468          0               1        579           2                 1
# 1469          0               2        336           1                 7
#
#       Education  EducationField  EmployeeCount  EnvironmentSatisfaction  \
# 0             1               1              0                        1
# 1             0               1              0                        2
# 2             1               4              0                        3
# 3             3               1              0                        3
# 4             0               3              0                        0
# ...         ...             ...            ...                      ...
# 1465          1               3              0                        2
# 1466          0               3              0                        3
# 1467          2               1              0                        1
# 1468          2               3              0                        3
# 1469          2               3              0                        1
#
#       Gender  ...  RelationshipSatisfaction  StockOptionLevel  \
# 0          0  ...                         0                 0
# 1          1  ...                         3                 1
# 2          1  ...                         1                 0
# 3          0  ...                         2                 0
# 4          1  ...                         3                 1
# ...      ...  ...                       ...               ...
# 1465       1  ...                         2                 1
# 1466       1  ...                         0                 1
# 1467       1  ...                         1                 1
# 1468       1  ...                         3                 0
# 1469       1  ...                         0                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                0
# 1                    10                      3                2
# 2                     7                      3                2
# 3                     8                      3                2
# 4                     6                      3                2
# ...                 ...                    ...              ...
# 1465                 17                      3                2
# 1466                  9                      5                2
# 1467                  6                      0                2
# 1468                 17                      3                1
# 1469                  6                      3                3
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager  Age_Years
# 0                        5         23
# 1                        7         31
# 2                        0         19
# 3                        0         15
# 4                        2          9
# ...                    ...        ...
# 1465                     3         18
# 1466                     7         21
# 1467                     3          9
# 1468                     8         31
# 1469                     2         16
#
# [1470 rows x 32 columns]

# %%
data.corr()
# Out:
#                           Attrition  BusinessTravel  DailyRate  Department  \
# Attrition                  1.000000        0.000074  -0.056605    0.063991
# BusinessTravel             0.000074        1.000000  -0.004103   -0.009044
# DailyRate                 -0.056605       -0.004103   1.000000    0.007796
# Department                 0.063991       -0.009044   0.007796    1.000000
# DistanceFromHome           0.077924       -0.024469  -0.004738    0.017225
# Education                 -0.031373        0.000757  -0.016550    0.007996
# EducationField             0.026846        0.023724   0.038129    0.013720
# EmployeeCount                   NaN             NaN        NaN         NaN
# EnvironmentSatisfaction   -0.103369        0.004174   0.018462   -0.019395
# Gender                     0.029453       -0.032981  -0.011194   -0.041583
# HourlyRate                -0.006846        0.026528   0.022916   -0.004144
# JobInvolvement            -0.130016        0.039062   0.046072   -0.024586
# JobLevel                  -0.169105        0.019311   0.003355    0.101963
# JobRole                    0.067151        0.002724  -0.009127    0.662431
# JobSatisfaction           -0.103481       -0.033962   0.030712    0.021001
# MaritalStatus              0.162070        0.024001  -0.069527    0.056073
# MonthlyIncome             -0.196165        0.025095   0.015784    0.157526
# MonthlyRate                0.015273       -0.014115  -0.032051    0.023898
# NumCompaniesWorked         0.043494        0.020875   0.037304   -0.035882
# OverTime                   0.246118        0.016543   0.008902    0.007481
# PercentSalaryHike         -0.013478       -0.029377   0.022339   -0.007840
# PerformanceRating          0.002889       -0.026341   0.000633   -0.024604
# RelationshipSatisfaction  -0.045872       -0.035986   0.008530   -0.022414
# StockOptionLevel          -0.137145       -0.016727   0.041786   -0.012193
# TotalWorkingYears         -0.171571        0.034144   0.014877   -0.015685
# TrainingTimesLastYear     -0.059478        0.015240   0.002227    0.036875
# WorkLifeBalance           -0.063939       -0.011256  -0.037791    0.026383
# YearsAtCompany            -0.136932       -0.014720  -0.032461    0.023308
# YearsInCurrentRole        -0.160545       -0.011497   0.010997    0.056315
# YearsSinceLastPromotion   -0.033019       -0.032591  -0.033431    0.040061
# YearsWithCurrManager      -0.156199       -0.022636  -0.025849    0.034282
# Age_Years                 -0.159205        0.024751   0.010557   -0.031882
#
#                           DistanceFromHome  Education  EducationField  \
# Attrition                         0.077924  -0.031373        0.026846
# BusinessTravel                   -0.024469   0.000757        0.023724
# DailyRate                        -0.004738  -0.016550        0.038129
# Department                        0.017225   0.007996        0.013720
# DistanceFromHome                  1.000000   0.021042        0.002013
# Education                         0.021042   1.000000       -0.039592
# EducationField                    0.002013  -0.039592        1.000000
# EmployeeCount                          NaN        NaN             NaN
# EnvironmentSatisfaction          -0.016075  -0.027128        0.043163
# Gender                           -0.001851  -0.016547       -0.002504
# HourlyRate                        0.031131   0.016775       -0.021941
# JobInvolvement                    0.008783   0.042438       -0.002655
# JobLevel                          0.005303   0.101589       -0.044933
# JobRole                          -0.001015   0.004236        0.015599
# JobSatisfaction                  -0.003669  -0.011296       -0.034401
# MaritalStatus                    -0.014437   0.004053        0.014420
# MonthlyIncome                     0.011962   0.124561       -0.044306
# MonthlyRate                       0.028298  -0.025694       -0.026343
# NumCompaniesWorked               -0.029251   0.126317       -0.008663
# OverTime                          0.025514  -0.020322        0.002259
# PercentSalaryHike                 0.040235  -0.011111       -0.011214
# PerformanceRating                 0.027110  -0.024539       -0.005614
# RelationshipSatisfaction          0.006557  -0.009118       -0.004378
# StockOptionLevel                  0.044872   0.018422       -0.016185
# TotalWorkingYears                 0.004560   0.148188       -0.027833
# TrainingTimesLastYear            -0.036942  -0.025100        0.049195
# WorkLifeBalance                  -0.026556   0.009819        0.041191
# YearsAtCompany                    0.009038   0.067737       -0.018987
# YearsInCurrentRole                0.018845   0.060236       -0.010506
# YearsSinceLastPromotion           0.010029   0.054254        0.002326
# YearsWithCurrManager              0.014406   0.069065       -0.004130
# Age_Years                        -0.001686   0.208034       -0.040873
#
#                           EmployeeCount  EnvironmentSatisfaction    Gender  \
# Attrition                           NaN                -0.103369  0.029453
# BusinessTravel                      NaN                 0.004174 -0.032981
# DailyRate                           NaN                 0.018462 -0.011194
# Department                          NaN                -0.019395 -0.041583
# DistanceFromHome                    NaN                -0.016075 -0.001851
# Education                           NaN                -0.027128 -0.016547
# EducationField                      NaN                 0.043163 -0.002504
# EmployeeCount                       NaN                      NaN       NaN
# EnvironmentSatisfaction             NaN                 1.000000  0.000508
# Gender                              NaN                 0.000508  1.000000
# HourlyRate                          NaN                -0.049857 -0.000478
# JobInvolvement                      NaN                -0.008278  0.017960
# JobLevel                            NaN                 0.001212 -0.039403
# JobRole                             NaN                -0.017321 -0.039723
# JobSatisfaction                     NaN                -0.006784  0.033252
# MaritalStatus                       NaN                -0.003593 -0.047183
# MonthlyIncome                       NaN                -0.015259 -0.044121
# MonthlyRate                         NaN                 0.037545 -0.041786
# NumCompaniesWorked                  NaN                 0.012594 -0.039147
# OverTime                            NaN                 0.070132 -0.041924
# PercentSalaryHike                   NaN                -0.031701  0.002733
# PerformanceRating                   NaN                -0.029548 -0.013859
# RelationshipSatisfaction            NaN                 0.007665  0.022868
# StockOptionLevel                    NaN                 0.003432  0.012716
# TotalWorkingYears                   NaN                -0.002900 -0.046875
# TrainingTimesLastYear               NaN                -0.019359 -0.038787
# WorkLifeBalance                     NaN                 0.027627 -0.002753
# YearsAtCompany                      NaN                 0.000657 -0.030797
# YearsInCurrentRole                  NaN                 0.018007 -0.041483
# YearsSinceLastPromotion             NaN                 0.016194 -0.026985
# YearsWithCurrManager                NaN                -0.004999 -0.030599
# Age_Years                           NaN                 0.010146 -0.036311
#
#                           ...  RelationshipSatisfaction  StockOptionLevel  \
# Attrition                 ...                 -0.045872         -0.137145
# BusinessTravel            ...                 -0.035986         -0.016727
# DailyRate                 ...                  0.008530          0.041786
# Department                ...                 -0.022414         -0.012193
# DistanceFromHome          ...                  0.006557          0.044872
# Education                 ...                 -0.009118          0.018422
# EducationField            ...                 -0.004378         -0.016185
# EmployeeCount             ...                       NaN               NaN
# EnvironmentSatisfaction   ...                  0.007665          0.003432
# Gender                    ...                  0.022868          0.012716
# HourlyRate                ...                  0.001330          0.050263
# JobInvolvement            ...                  0.034297          0.021523
# JobLevel                  ...                  0.021642          0.013984
# JobRole                   ...                 -0.020218         -0.019171
# JobSatisfaction           ...                 -0.012454          0.010690
# MaritalStatus             ...                  0.022549         -0.662577
# MonthlyIncome             ...                  0.005688          0.023343
# MonthlyRate               ...                 -0.003874         -0.034305
# NumCompaniesWorked        ...                  0.052733          0.030075
# OverTime                  ...                  0.048493         -0.000449
# PercentSalaryHike         ...                 -0.040490          0.007528
# PerformanceRating         ...                 -0.031351          0.003506
# RelationshipSatisfaction  ...                  1.000000         -0.045952
# StockOptionLevel          ...                 -0.045952          1.000000
# TotalWorkingYears         ...                  0.023861          0.010203
# TrainingTimesLastYear     ...                  0.002497          0.011274
# WorkLifeBalance           ...                  0.019604          0.004129
# YearsAtCompany            ...                  0.018542          0.015749
# YearsInCurrentRole        ...                 -0.015123          0.050818
# YearsSinceLastPromotion   ...                  0.033493          0.014352
# YearsWithCurrManager      ...                 -0.000867          0.024698
# Age_Years                 ...                  0.053535          0.037510
#
#                           TotalWorkingYears  TrainingTimesLastYear  \
# Attrition                         -0.171571              -0.059478
# BusinessTravel                     0.034144               0.015240
# DailyRate                          0.014877               0.002227
# Department                        -0.015685               0.036875
# DistanceFromHome                   0.004560              -0.036942
# Education                          0.148188              -0.025100
# EducationField                    -0.027833               0.049195
# EmployeeCount                           NaN                    NaN
# EnvironmentSatisfaction           -0.002900              -0.019359
# Gender                            -0.046875              -0.038787
# HourlyRate                        -0.002306              -0.008548
# JobInvolvement                    -0.005603              -0.015338
# JobLevel                           0.782398              -0.018191
# JobRole                           -0.145392               0.001342
# JobSatisfaction                   -0.020241              -0.005779
# MaritalStatus                     -0.078032               0.010629
# MonthlyIncome                      0.705164              -0.028533
# MonthlyRate                        0.026188               0.001187
# NumCompaniesWorked                 0.237698              -0.066054
# OverTime                           0.012678              -0.079113
# PercentSalaryHike                 -0.020468              -0.005221
# PerformanceRating                  0.006823              -0.015579
# RelationshipSatisfaction           0.023861               0.002497
# StockOptionLevel                   0.010203               0.011274
# TotalWorkingYears                  1.000000              -0.035644
# TrainingTimesLastYear             -0.035644               1.000000
# WorkLifeBalance                    0.001073               0.028072
# YearsAtCompany                     0.626777               0.003349
# YearsInCurrentRole                 0.460257              -0.005738
# YearsSinceLastPromotion            0.404473              -0.002067
# YearsWithCurrManager               0.459339              -0.004096
# Age_Years                          0.680409              -0.019621
#
#                           WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Attrition                       -0.063939       -0.136932           -0.160545
# BusinessTravel                  -0.011256       -0.014720           -0.011497
# DailyRate                       -0.037791       -0.032461            0.010997
# Department                       0.026383        0.023308            0.056315
# DistanceFromHome                -0.026556        0.009038            0.018845
# Education                        0.009819        0.067737            0.060236
# EducationField                   0.041191       -0.018987           -0.010506
# EmployeeCount                         NaN             NaN                 NaN
# EnvironmentSatisfaction          0.027627        0.000657            0.018007
# Gender                          -0.002753       -0.030797           -0.041483
# HourlyRate                      -0.004607       -0.020122           -0.024106
# JobInvolvement                  -0.014617       -0.020785            0.008717
# JobLevel                         0.037818        0.535603            0.389447
# JobRole                          0.027764       -0.082870           -0.028354
# JobSatisfaction                 -0.019459       -0.003929           -0.002305
# MaritalStatus                    0.014708       -0.060648           -0.065822
# MonthlyIncome                    0.034372        0.489707            0.406535
# MonthlyRate                      0.008326       -0.024466           -0.012916
# NumCompaniesWorked              -0.008366       -0.118314           -0.090754
# OverTime                        -0.027092       -0.012559           -0.029758
# PercentSalaryHike               -0.003280       -0.035745           -0.001520
# PerformanceRating                0.002572        0.003740            0.034986
# RelationshipSatisfaction         0.019604        0.018542           -0.015123
# StockOptionLevel                 0.004129        0.015749            0.050818
# TotalWorkingYears                0.001073        0.626777            0.460257
# TrainingTimesLastYear            0.028072        0.003349           -0.005738
# WorkLifeBalance                  1.000000        0.012400            0.049856
# YearsAtCompany                   0.012400        1.000000            0.764141
# YearsInCurrentRole               0.049856        0.764141            1.000000
# YearsSinceLastPromotion          0.008941        0.620602            0.548056
# YearsWithCurrManager             0.002759        0.774552            0.714365
# Age_Years                       -0.021490        0.309796            0.212901
#
#                           YearsSinceLastPromotion  YearsWithCurrManager  \
# Attrition                               -0.033019             -0.156199
# BusinessTravel                          -0.032591             -0.022636
# DailyRate                               -0.033431             -0.025849
# Department                               0.040061              0.034282
# DistanceFromHome                         0.010029              0.014406
# Education                                0.054254              0.069065
# EducationField                           0.002326             -0.004130
# EmployeeCount                                 NaN                   NaN
# EnvironmentSatisfaction                  0.016194             -0.004999
# Gender                                  -0.026985             -0.030599
# HourlyRate                              -0.026716             -0.020123
# JobInvolvement                          -0.024184              0.025976
# JobLevel                                 0.353885              0.375281
# JobRole                                 -0.046384             -0.041150
# JobSatisfaction                         -0.018214             -0.027656
# MaritalStatus                           -0.030915             -0.038570
# MonthlyIncome                            0.324573              0.377748
# MonthlyRate                              0.001152             -0.037059
# NumCompaniesWorked                      -0.036814             -0.110319
# OverTime                                -0.012239             -0.041586
# PercentSalaryHike                       -0.022154             -0.011985
# PerformanceRating                        0.017896              0.022827
# RelationshipSatisfaction                 0.033493             -0.000867
# StockOptionLevel                         0.014352              0.024698
# TotalWorkingYears                        0.404473              0.459339
# TrainingTimesLastYear                   -0.002067             -0.004096
# WorkLifeBalance                          0.008941              0.002759
# YearsAtCompany                           0.620602              0.774552
# YearsInCurrentRole                       0.548056              0.714365
# YearsSinceLastPromotion                  1.000000              0.510224
# YearsWithCurrManager                     0.510224              1.000000
# Age_Years                                0.216513              0.202089
#
#                           Age_Years
# Attrition                 -0.159205
# BusinessTravel             0.024751
# DailyRate                  0.010557
# Department                -0.031882
# DistanceFromHome          -0.001686
# Education                  0.208034
# EducationField            -0.040873
# EmployeeCount                   NaN
# EnvironmentSatisfaction    0.010146
# Gender                    -0.036311
# HourlyRate                 0.024287
# JobInvolvement             0.029820
# JobLevel                   0.509604
# JobRole                   -0.122427
# JobSatisfaction           -0.004892
# MaritalStatus             -0.095029
# MonthlyIncome              0.472198
# MonthlyRate                0.028362
# NumCompaniesWorked         0.299635
# OverTime                   0.028062
# PercentSalaryHike          0.003634
# PerformanceRating          0.001904
# RelationshipSatisfaction   0.053535
# StockOptionLevel           0.037510
# TotalWorkingYears          0.680409
# TrainingTimesLastYear     -0.019621
# WorkLifeBalance           -0.021490
# YearsAtCompany             0.309796
# YearsInCurrentRole         0.212901
# YearsSinceLastPromotion    0.216513
# YearsWithCurrManager       0.202089
# Age_Years                  1.000000
#
# [32 rows x 32 columns]

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr() , annot = True , fmt = '.0%')
# Out:
# <Axes: >

# %%
X = data.iloc[:,1 : data.shape[1]].values
y = data.iloc[:,0].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X , y , test_size = 0.2 , random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier(n_estimators = 10 , criterion = 'entropy' , random_state = 0)
forest.fit(X_train , y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
forest.score(X_train , y_train)
# Out:
# 0.9829931972789115

# %%
from sklearn.metrics import confusion_matrix

# %%
conf = confusion_matrix(y_test , forest.predict(X_test))
TN = conf[0][0]
TP = conf[1][1]
FN = conf[1][0]
FP = conf[0][1]

print(conf)
print('Model Testing Accuracy = {}'.format(  (TP + TN) / (TP + TN + FN + FP)  ))
# Out:
# [[243   2]
#  [ 43   6]]
# Model Testing Accuracy = 0.8469387755102041
